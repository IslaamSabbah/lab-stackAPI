# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
import requests
import json
from stackapi import StackAPI
import pandas as pd
import datetime

# %%
startdate=1569888000
enddate=1572480000

# %%
SITE = StackAPI("stackoverflow")
answers = SITE.fetch('/answers',fromdate=startdate , todate=enddate)
#questions = SITE.fetch('questions')
answers
# Out:
# trRprAJA2nE-ib9gtEBy4Hw=k-s128',
#     'display_name': 'Crystal Lambert',
#     'link': 'https://stackoverflow.com/users/12294281/crystal-lambert'},
#    'is_accepted': True,
#    'score': 3,
#    'last_activity_date': 1573079004,
#    'last_edit_date': 1573079004,
#    'creation_date': 1572393413,
#    'answer_id': 58616962,
#    'question_id': 58605962},
#   {'owner': {'reputation': 1,
#     'user_id': 12299764,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/0004398c7cf2f04fe29c61aa96f705ff?s=128&d=identicon&r=PG',
#     'display_name': 'Invoke Logic',
#     'link': 'https://stackoverflow.com/users/12299764/invoke-logic'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1573078669,
#    'last_edit_date': 1573078669,
#    'creation_date': 1572468054,
#    'answer_id': 58633329,
#    'question_id': 58633252},
#   {'owner': {'reputation': 192,
#     'user_id': 4288922,
#     'user_type': 'registered',
# ...

# %%
SITE = StackAPI("stackoverflow")
questions = SITE.fetch('/questions',fromdate=startdate , todate=enddate)
#questions = SITE.fetch('questions')
questions
# Out:
# 90/davidhmpham'},
#    'is_answered': True,
#    'view_count': 58,
#    'accepted_answer_id': 58328741,
#    'answer_count': 1,
#    'score': 2,
#    'last_activity_date': 1573675415,
#    'creation_date': 1570716224,
#    'last_edit_date': 1570717559,
#    'question_id': 58324817,
#    'link': 'https://stackoverflow.com/questions/58324817/pandas-multi-index-changing-float-to-string',
#    'title': 'Pandas Multi Index Changing Float to String'},
#   {'tags': ['azure-devops'],
#    'owner': {'reputation': 416,
#     'user_id': 292718,
#     'user_type': 'registered',
#     'accept_rate': 54,
#     'profile_image': 'https://www.gravatar.com/avatar/096eff8fde3de54c4d106c6c781e23c2?s=128&d=identicon&r=PG',
#     'display_name': 'michaelkoss',
#     'link': 'https://stackoverflow.com/users/292718/michaelkoss'},
#    'is_answered': True,
#    'view_count': 20,
#    'accepted_answer_id': 58630190,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1573675022,
# ...

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
#

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
# your code here
questions_vote=SITE.fetch('questions', fromdate=1573117200 , todate=1573160400, min=5 , tagged='python' , sort='votes')

# %%
questions_vote
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'tags': ['python', 'multiprocessing'],
#    'owner': {'reputation': 59625,
#     'user_id': 76701,
#     'user_type': 'registered',
#     'accept_rate': 72,
#     'profile_image': 'https://www.gravatar.com/avatar/d24c45635a5171615a7cdb936f36daad?s=128&d=identicon&r=PG',
#     'display_name': 'Ram Rachum',
#     'link': 'https://stackoverflow.com/users/76701/ram-rachum'},
#    'is_answered': False,
#    'view_count': 86,
#    'answer_count': 1,
#    'score': 6,
#    'last_activity_date': 1573218959,
#    'creation_date': 1573136852,
#    'question_id': 58750861,
#    'link': 'https://stackoverflow.com/questions/58750861/python-multiprocessing-running-a-process-after-its-parent-exited',
#    'title': 'Python multiprocessing: Running a process after its parent exited'},
#   {'tags': ['python',
#     'opencv',
#     'image-processing',
#     'computer-vision',
# ...

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
answers_3=SITE.fetch('answers', ids=[6784,6473])
# your code here

# %%
answers_3
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'owner': {'reputation': 28359,
#     'user_id': 758,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/0b4adc19284ed0751844d610555dc6b2?s=128&d=identicon&r=PG',
#     'display_name': 'Mark Renouf',
#     'link': 'https://stackoverflow.com/users/758/mark-renouf'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1218291583,
#    'creation_date': 1218291583,
#    'answer_id': 6784,
#    'question_id': 6778}]}
